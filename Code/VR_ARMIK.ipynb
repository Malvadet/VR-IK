# %% [markdown]
# <a href="https://colab.research.google.com/github/Malvadet/VR-IK/blob/main/Code/VR_ARMIK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('imu_data-0_Merged.csv')
print(df)
# Out:
#         imu                 server_time  arduino_time   ax   ay    az    gx  \
# 0         0  2023-03-07T16:00:44.396405        646967  238 -174  1643  -961
# 1         0  2023-03-07T16:00:44.405341        646975  238 -174  1643  -961
# 2         0  2023-03-07T16:00:44.410806        646981  238 -183  1619  -941
# 3         0  2023-03-07T16:00:44.415641        646986  238 -183  1619  -941
# 4         0  2023-03-07T16:00:44.419967        646990  238 -183  1619  -941
# ...     ...                         ...           ...  ...  ...   ...   ...
# 120898    0  2023-03-07T16:10:38.683563       1241264  246 -199  1635 -1158
# 120899    0  2023-03-07T16:10:38.688079       1241269  246 -199  1635 -1158
# 120900    0  2023-03-07T16:10:38.692444       1241273  246 -199  1635 -1158
# 120901    0  2023-03-07T16:10:38.697377       1241278  261 -246  1597 -1201
# 120902    0  2023-03-07T16:10:38.701616       1241282  261 -246  1597 -1201
#
#          gy   gz   mx   my  mz
# ...

# %%
df.plot(x="arduino_time", y=["ax", "ay", "az"], figsize=(20,10))
plt.show()
#plt.plot(df["arduino_time"], df["ax"])

# %%
#Elbow
lhr = pd.read_csv('Elbow.csv', delimiter=';')
print(lhr)
# Out:
#                         Timestamp  FrameCount Manufacturer  \
# 0      2023-03-07T16:00:55.719429           3          HTC
# 1      2023-03-07T16:00:55.720428           3          HTC
# 2      2023-03-07T16:00:55.720428           3          HTC
# 3      2023-03-07T16:00:55.720428           3          HTC
# 4      2023-03-07T16:00:55.720428           3          HTC
# ...                           ...         ...          ...
# 29061  2023-03-07T16:10:36.625003       51988          HTC
# 29062  2023-03-07T16:10:36.648003       51990          HTC
# 29063  2023-03-07T16:10:36.670000       51992          HTC
# 29064  2023-03-07T16:10:36.681002       51993          HTC
# 29065  2023-03-07T16:10:36.704001       51995          HTC
#
#                                                 Name  SerialNumber  \
# 0      OpenVR Controller(VIVE Tracker 3.0 MV) - Left  LHR-9E483859
# 1      OpenVR Controller(VIVE Tracker 3.0 MV) - Left  LHR-9E483859
# ...

# %%
position = []
for t in range(lhr.shape[0]):
            line = [float(lhr.Position[t].split(',')[0][1:]), float(lhr.Position[t].split(',')[1]), float(lhr.Position[t].split(',')[2][:-1])]
            position.append(line)

# %%
len(position)
# Out:
# 15598

# %%
plt.figure(figsize=(20,10))
plt.plot(position)
plt.show()
